# %% [markdown]
# # LES JOINTURES
# Les jointures permettene de réuir les données de plpusoeurs tables sur une colonne commune.
#
#
# *   Lef-join : conserve toutes les données de la table de gauche er ajoute celles de kak tables de droite.
# *   right-joint : meme principe
#
#
# *   innner-join : conserve les données cillunes aux deux tables
# *   outer-join : conserve toutes les données

# %%
import pandas as pd
