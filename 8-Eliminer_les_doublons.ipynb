# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

# Remplacez 'Mon_Dossier/mon_fichier.csv' par le chemin réel de votre fichier sur Google Drive
file_path = '/content/drive/My Drive/SENEGAL/DATA/DATA_CSV/curiexplore-pays.csv'

try:
    df = pd.read_csv(file_path, sep=";")
    print(f"Fichier '{file_path}' chargé avec succès.")
    display(df.head())
except FileNotFoundError:
    print(f"Erreur: Le fichier '{file_path}' n'a pas été trouvé. Veuillez vérifier le chemin.")
except Exception as e:
    print(f"Une erreur est survenue lors du chargement du fichier: {e}")
# Out:
# Mounted at /content/drive
# Fichier '/content/drive/My Drive/SENEGAL/DATA/DATA_CSV/curiexplore-pays.csv' chargé avec succès.
#   iso3                name_en   name_fr name_native iso2          borders  \
# 0  BEN                  Benin     Bénin       Bénin   BJ  BFA,NER,NGA,TGO
# 1  CAN                 Canada    Canada      Canada   CA              USA
# 2  MDA  Moldova (Republic of)  Moldavie     Moldova   MD          ROU,UKR
# 3  MNG               Mongolia  Mongolie  Монгол улс   MN          CHN,RUS
# 4  ALB                Albania   Albanie   Shqipëria   AL  MNE,GRC,MKD,KOS
#
#                                                 flag       latlng wikidata  \
# 0  https://upload.wikimedia.org/wikipedia/commons...    9.5, 2.25     Q962
# 1  https://upload.wikimedia.org/wikipedia/commons...  60.0, -95.0      Q16
# 2  https://upload.wikimedia.org/wikipedia/commons...   47.0, 29.0     Q217
# 3  https://upload.wikimedia.org/wikipedia/commons...  46.0, 105.0     Q711
# 4  https://upload.wikimedia.org/wikipedia/commons...   41.0, 20.0     Q222
#
#    bologne  ...   ue28     g7    g20  \
# 0    False  ...  False  False  False
# 1    False  ...  False   True   True
# 2     True  ...  False  False  False
# 3    False  ...  False  False  False
# 4     True  ...  False  False  False
#
#                                             geometry  ue_euro  oecd_obs  \
# 0  {"coordinates": [[[2.691701694356254, 6.258817...    False     False
# 1  {"coordinates": [[[[-63.6645, 46.55001], [-62....    False     False
# 2  {"coordinates": [[[26.619336785597795, 48.2207...    False     False
# 3  {"coordinates": [[[87.7512642760767, 49.297197...    False     False
# 4  {"coordinates": [[[20.590247430104906, 41.8554...    False     False
#
#    oecd_members_old  brics  code_num_3      cog
# 0             False  False       204.0  99327.0
# 1              True  False       124.0  99401.0
# 2             False  False       498.0  99151.0
# 3             False  False       496.0  99242.0
# 4             False  False         8.0  99125.0
#
# [5 rows x 51 columns]

# %%
df.drop_duplicates() #Fonction drop_duplicates qui permet de supprimer les doublons
# Out:
#     iso3                name_en         name_fr   name_native iso2  \
# 0    BEN                  Benin           Bénin         Bénin   BJ
# 1    CAN                 Canada          Canada        Canada   CA
# 2    MDA  Moldova (Republic of)        Moldavie       Moldova   MD
# 3    MNG               Mongolia        Mongolie    Монгол улс   MN
# 4    ALB                Albania         Albanie     Shqipëria   AL
# ..   ...                    ...             ...           ...  ...
# 211  PAK               Pakistan        Pakistan      Pakistan   PK
# 212  PRY               Paraguay        Paraguay      Paraguay   PY
# 213  ROU                Romania        Roumanie       România   RO
# 214  SVN               Slovenia        Slovénie     Slovenija   SI
# 215  ZAF           South Africa  Afrique du Sud  South Africa   ZA
#
#                      borders  \
# 0            BFA,NER,NGA,TGO
# 1                        USA
# 2                    ROU,UKR
# 3                    CHN,RUS
# 4            MNE,GRC,MKD,KOS
# ..                       ...
# 211          AFG,CHN,IND,IRN
# 212              ARG,BOL,BRA
# 213      BGR,HUN,MDA,SRB,UKR
# 214          AUT,HRV,ITA,HUN
# 215  BWA,LSO,MOZ,NAM,SWZ,ZWE
#
#                                                   flag  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 211  https://upload.wikimedia.org/wikipedia/commons...
# 212  https://upload.wikimedia.org/wikipedia/commons...
# 213  https://upload.wikimedia.org/wikipedia/commons...
# 214  https://upload.wikimedia.org/wikipedia/commons...
# 215  https://upload.wikimedia.org/wikipedia/commons...
#
#                        latlng wikidata  bologne  ...   ue28     g7    g20  \
# 0                   9.5, 2.25     Q962    False  ...  False  False  False
# 1                 60.0, -95.0      Q16    False  ...  False   True   True
# 2                  47.0, 29.0     Q217     True  ...  False  False  False
# 3                 46.0, 105.0     Q711    False  ...  False  False  False
# 4                  41.0, 20.0     Q222     True  ...  False  False  False
# ..                        ...      ...      ...  ...    ...    ...    ...
# 211                30.0, 70.0     Q843    False  ...  False  False  False
# 212              -23.0, -58.0     Q733    False  ...  False  False  False
# 213                46.0, 25.0     Q218     True  ...   True  False  False
# 214  46.11666666, 14.81666666     Q215     True  ...   True  False  False
# 215               -29.0, 24.0     Q258    False  ...  False  False   True
#
#                                               geometry  ue_euro  oecd_obs  \
# 0    {"coordinates": [[[2.691701694356254, 6.258817...    False     False
# 1    {"coordinates": [[[[-63.6645, 46.55001], [-62....    False     False
# 2    {"coordinates": [[[26.619336785597795, 48.2207...    False     False
# 3    {"coordinates": [[[87.7512642760767, 49.297197...    False     False
# 4    {"coordinates": [[[20.590247430104906, 41.8554...    False     False
# ..                                                 ...      ...       ...
# 211  {"coordinates": [[[75.15802778514092, 37.13303...    False      True
# 212  {"coordinates": [[[-62.685057135657885, -22.24...    False     False
# 213  {"coordinates": [[[22.710531447040495, 47.8821...    False      True
# 214  {"coordinates": [[[13.806475457421527, 46.5093...     True     False
# 215  {"coordinates": [[[31.521001417778876, -29.257...    False     False
#
#      oecd_members_old  brics  code_num_3      cog
# 0               False  False       204.0  99327.0
# 1                True  False       124.0  99401.0
# 2               False  False       498.0  99151.0
# 3               False  False       496.0  99242.0
# 4               False  False         8.0  99125.0
# ..                ...    ...         ...      ...
# 211             False  False       586.0  99213.0
# 212             False  False       600.0  99421.0
# 213             False  False       642.0  99114.0
# 214             False  False       705.0  99145.0
# 215             False   True       710.0  99303.0
#
# [216 rows x 51 columns]

# %%
df.drop_duplicates(subset='iso2',keep='last')
# Out:
#     iso3                name_en         name_fr   name_native iso2  \
# 0    BEN                  Benin           Bénin         Bénin   BJ
# 1    CAN                 Canada          Canada        Canada   CA
# 2    MDA  Moldova (Republic of)        Moldavie       Moldova   MD
# 3    MNG               Mongolia        Mongolie    Монгол улс   MN
# 4    ALB                Albania         Albanie     Shqipëria   AL
# ..   ...                    ...             ...           ...  ...
# 211  PAK               Pakistan        Pakistan      Pakistan   PK
# 212  PRY               Paraguay        Paraguay      Paraguay   PY
# 213  ROU                Romania        Roumanie       România   RO
# 214  SVN               Slovenia        Slovénie     Slovenija   SI
# 215  ZAF           South Africa  Afrique du Sud  South Africa   ZA
#
#                      borders  \
# 0            BFA,NER,NGA,TGO
# 1                        USA
# 2                    ROU,UKR
# 3                    CHN,RUS
# 4            MNE,GRC,MKD,KOS
# ..                       ...
# 211          AFG,CHN,IND,IRN
# 212              ARG,BOL,BRA
# 213      BGR,HUN,MDA,SRB,UKR
# 214          AUT,HRV,ITA,HUN
# 215  BWA,LSO,MOZ,NAM,SWZ,ZWE
#
#                                                   flag  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 211  https://upload.wikimedia.org/wikipedia/commons...
# 212  https://upload.wikimedia.org/wikipedia/commons...
# 213  https://upload.wikimedia.org/wikipedia/commons...
# 214  https://upload.wikimedia.org/wikipedia/commons...
# 215  https://upload.wikimedia.org/wikipedia/commons...
#
#                        latlng wikidata  bologne  ...   ue28     g7    g20  \
# 0                   9.5, 2.25     Q962    False  ...  False  False  False
# 1                 60.0, -95.0      Q16    False  ...  False   True   True
# 2                  47.0, 29.0     Q217     True  ...  False  False  False
# 3                 46.0, 105.0     Q711    False  ...  False  False  False
# 4                  41.0, 20.0     Q222     True  ...  False  False  False
# ..                        ...      ...      ...  ...    ...    ...    ...
# 211                30.0, 70.0     Q843    False  ...  False  False  False
# 212              -23.0, -58.0     Q733    False  ...  False  False  False
# 213                46.0, 25.0     Q218     True  ...   True  False  False
# 214  46.11666666, 14.81666666     Q215     True  ...   True  False  False
# 215               -29.0, 24.0     Q258    False  ...  False  False   True
#
#                                               geometry  ue_euro  oecd_obs  \
# 0    {"coordinates": [[[2.691701694356254, 6.258817...    False     False
# 1    {"coordinates": [[[[-63.6645, 46.55001], [-62....    False     False
# 2    {"coordinates": [[[26.619336785597795, 48.2207...    False     False
# 3    {"coordinates": [[[87.7512642760767, 49.297197...    False     False
# 4    {"coordinates": [[[20.590247430104906, 41.8554...    False     False
# ..                                                 ...      ...       ...
# 211  {"coordinates": [[[75.15802778514092, 37.13303...    False      True
# 212  {"coordinates": [[[-62.685057135657885, -22.24...    False     False
# 213  {"coordinates": [[[22.710531447040495, 47.8821...    False      True
# 214  {"coordinates": [[[13.806475457421527, 46.5093...     True     False
# 215  {"coordinates": [[[31.521001417778876, -29.257...    False     False
#
#      oecd_members_old  brics  code_num_3      cog
# 0               False  False       204.0  99327.0
# 1                True  False       124.0  99401.0
# 2               False  False       498.0  99151.0
# 3               False  False       496.0  99242.0
# 4               False  False         8.0  99125.0
# ..                ...    ...         ...      ...
# 211             False  False       586.0  99213.0
# 212             False  False       600.0  99421.0
# 213             False  False       642.0  99114.0
# 214             False  False       705.0  99145.0
# 215             False   True       710.0  99303.0
#
# [215 rows x 51 columns]
